# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd

# %%
# загрузка датасета features.csv и data_train.csv

data = dd.read_csv('git_ignore_files/features.csv', sep='\t', blocksize=15e6)
data_train = pd.read_csv('git_ignore_files/data_train.csv')

# %%
# отделение из features.csv только абонентов из data_train.csv

list_id_train = list(data_train['id'].unique())   # список id-шников
data = data[data['id'].isin(list_id_train)].compute()

# %%
# data.to_csv('files_model/id_train.csv', index=False)

# %%
# data = pd.read_csv('files_model/id_train.csv')
# data_train = pd.read_csv('data_train.csv')

# %%
# объединение датасетов

data_end = pd.merge_asof(data_train.sort_values('buy_time'), data.sort_values('buy_time'), on='buy_time', by='id', direction='nearest')

# %%
# просмотр полученного результата

data_end
# Out:
#         Unnamed: 0_x       id  vas_id    buy_time  target  Unnamed: 0_y  \
# 0             578818  2582523     2.0  1531083600     0.0       3360134
# 1             603994  1292549     2.0  1531083600     0.0       2915346
# 2             293389  4053116     1.0  1531083600     0.0       1569112
# 3             293387  4158361     2.0  1531083600     0.0        597622
# 4             254350  3754468     4.0  1531083600     0.0       2376979
# ...              ...      ...     ...         ...     ...           ...
# 831648        535199   555080     5.0  1546203600     0.0       2043207
# 831649        535198  1729471     5.0  1546203600     0.0        286598
# 831650        535136  3676177     2.0  1546203600     0.0       2151141
# 831651        535090  2255038     2.0  1546203600     0.0        311341
# 831652        831652  3022610     2.0  1546203600     0.0       2556316
#
#                  0           1           2           3  ...          243  \
# 0       314.560029    9.290888  342.989214    7.523202  ...  6488.626154
# 1        93.880029 -217.499112   79.939214 -270.106798  ...  -977.373846
# 2       125.110029  152.190888  111.169214  107.213202  ...  -956.373846
# 3        -7.829971 -266.839112  -20.500786 -304.196798  ...  1257.626154
# 4        83.620029  535.610888   72.219214  503.343202  ...  -977.373846
# ...            ...         ...         ...         ...  ...          ...
# 831648  -96.799971 -408.179112 -110.740786 -460.786798  ...  -977.373846
# 831649  -86.209971 -397.589112 -100.150786 -450.196798  ...  -977.373846
# 831650  -96.799971 -408.179112 -110.740786 -460.786798  ...  -977.373846
# 831651  -96.799971   49.450888 -104.390786  219.293202  ...  -977.373846
# 831652  -49.339971 -218.339112   73.139214  145.093202  ...  -977.373846
#
#                244        245         246         247        248       249  \
# 0      -574.770792 -24.996269  121.369552  142.252276 -16.832889 -0.694428
# 1      -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 2      -613.770792 -18.996269  761.369552 -213.747724  26.167111 -0.694428
# 3       495.229208 -19.996269  -37.630448 -108.747724 -25.832889 -0.694428
# 4      -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# ...            ...        ...         ...         ...        ...       ...
# 831648 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831649 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831650 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831651 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831652 -613.770792 -25.996269  -37.630448 -303.747724 -25.832889 -0.694428
#
#               250      251  252
# 0      -11.175933 -0.45614  0.0
# 1      -12.175933 -0.45614  0.0
# 2       39.824067 -0.45614  1.0
# 3      -12.175933 -0.45614  1.0
# 4      -12.175933 -0.45614  0.0
# ...           ...      ...  ...
# 831648 -12.175933 -0.45614  0.0
# 831649 -12.175933 -0.45614  0.0
# 831650 -12.175933 -0.45614  0.0
# 831651 -12.175933 -0.45614  0.0
# 831652 -12.175933 -0.45614  0.0
#
# [831653 rows x 259 columns]

# %%
# это просто пустая строка))))

# %%
# сохранение объединенных данных для дальнейшего тестирования

data_end.to_csv('git_ignore_files/data_merge_asof.csv', index=False)

# %%
# data = pd.read_csv('files_model/data_merge_asof.csv')

# %%
# просмотр соотношения классов в датасете

data_end[data_end['target'] == 1].shape[0] / data_end.shape[0]
# Out:
# 0.07236912510385943

# %%
# отбор случайных индексов строк нулевых классов в количестве равном кол-ву строк единичных

ind_0 = np.random.choice(data_end[data_end['target'] == 0].index, size=data_end[data_end['target'] == 1].shape[0], replace=False)

# %%
# получение индексов единичных классов и объединение в один список

ind_1 = data_end[data_end['target'] == 1].index
print(ind_1.shape)
ind_ = list(ind_0) + list(ind_1)
len(ind_)
# Out:
# (60186,)
# 120372

# %%
# получение датасета для тренировки с уравненными классами 

data_train = data_end[data_end.index.isin(list(ind_))]
data_train
# Out:
#         Unnamed: 0_x       id  vas_id    buy_time  target  Unnamed: 0_y  \
# 0             578818  2582523     2.0  1531083600     0.0       3360134
# 6             604051   981791     2.0  1531083600     0.0       1898019
# 10            604076  3102489     1.0  1531083600     1.0        232405
# 12            703501  4232031     2.0  1531083600     0.0        235626
# 16            703493   380185     2.0  1531083600     0.0        192209
# ...              ...      ...     ...         ...     ...           ...
# 831623        534958   375662     2.0  1546203600     0.0       2110047
# 831628        534769  3782939     6.0  1546203600     1.0       4249411
# 831629        534716  1578619     6.0  1546203600     1.0       2654859
# 831646        535243  1623049     6.0  1546203600     1.0       4390996
# 831652        831652  3022610     2.0  1546203600     0.0       2556316
#
#                  0           1           2           3  ...          243  \
# 0       314.560029    9.290888  342.989214    7.523202  ...  6488.626154
# 6       -81.129971 -392.509112  -95.070786 -445.116798  ...  -977.373846
# 10      -96.799971 -408.179112 -110.740786 -460.786798  ...  -443.373846
# 12      -91.959971 -354.749112 -105.900786 -407.356798  ...  -977.373846
# 16      654.040029  401.980888  640.099214  351.833202  ...  -911.373846
# ...            ...         ...         ...         ...  ...          ...
# 831623  430.340029  118.960888  416.399214   66.353202  ...  -969.373846
# 831628  -96.799971 -408.179112 -110.740786 -460.786798  ...  -977.373846
# 831629  -96.799971  -38.659112 -110.740786  -91.266798  ...  -908.373846
# 831646  -88.689971 -375.059112 -102.630786 -427.666798  ...  -977.373846
# 831652  -49.339971 -218.339112   73.139214  145.093202  ...  -977.373846
#
#                244        245         246         247        248       249  \
# 0      -574.770792 -24.996269  121.369552  142.252276 -16.832889 -0.694428
# 6      -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 10      -80.770792  37.003731   21.369552  142.252276   8.167111 -0.694428
# 12     -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 16     -552.770792 -25.996269  -37.630448 -278.747724 -24.832889 -0.694428
# ...            ...        ...         ...         ...        ...       ...
# 831623 -613.770792 -25.996269  -37.630448  -17.747724  40.167111 -0.694428
# 831628 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831629 -545.770792 -25.996269  -37.630448 -101.747724 -24.832889 -0.694428
# 831646 -613.770792 -25.996269  -37.630448 -306.747724 -25.832889 -0.694428
# 831652 -613.770792 -25.996269  -37.630448 -303.747724 -25.832889 -0.694428
#
#               250      251  252
# 0      -11.175933 -0.45614  0.0
# 6      -12.175933 -0.45614  0.0
# 10      19.824067  1.54386  1.0
# 12     -12.175933 -0.45614  0.0
# 16     -11.175933 -0.45614  1.0
# ...           ...      ...  ...
# 831623 -10.175933 -0.45614  0.0
# 831628 -12.175933 -0.45614  0.0
# 831629 -12.175933 -0.45614  0.0
# 831646 -12.175933 -0.45614  0.0
# 831652 -12.175933 -0.45614  0.0
#
# [120372 rows x 259 columns]

# %%
# сохранение в файл для дальнейшей обработки

data_train.to_csv('git_ignore_files/data_train_merge_120k.csv', index=False)
